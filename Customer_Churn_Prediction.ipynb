# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
# we dont have any null values in here
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# we need to drop the customerID as it is useless for the model
df.drop('customerID',axis='columns',inplace=True)

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4465    Male              0      No         No      31           No
# 803   Female              0     Yes         No      46          Yes
# 5978  Female              0      No         No      46          Yes
# 5886  Female              0     Yes        Yes      47          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 4465  No phone service             DSL                   No
# 803                 No             DSL                   No
# 5978               Yes     Fiber optic                  Yes
# 5886                No              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 4465                   No                  Yes                   No
# 803                   Yes                   No                  Yes
# 5978                  Yes                   No                   No
# 5886  No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 4465                  Yes                  Yes        One year
# 803                   Yes                   No        Two year
# 5978                   No                   No  Month-to-month
# 5886  No internet service  No internet service        Two year
#
#      PaperlessBilling            PaymentMethod  MonthlyCharges TotalCharges  \
# 4465              Yes         Electronic check           50.05       1523.4
# 803               Yes  Credit card (automatic)           64.20       3009.5
# 5978               No             Mailed check           84.25       3847.6
# 5886               No             Mailed check           19.75        948.9
#
#      Churn
# 4465    No
# 803     No
# 5978    No
# 5886    No

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
df['SeniorCitizen'].value_counts()
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#FFC0CB"]
plt.figure(figsize=(20,6))
counts = df['gender'].value_counts()
explode = (0,0.1)
counts.plot(kind='pie',fontsize=12,colors=colors,explode=explode,autopct = '%.1f%%')
plt.title('Males vs Females')
plt.xlabel('Gender',weight='bold',color='#2F0F5D',fontsize=14,labelpad=20)
plt.ylabel('Counts',weight='bold',color='#FFC0CB',fontsize=14,labelpad=20)
plt.legend(labels = counts.index,loc='best')
plt.show()

# %%
#Convert 'Male' to 0 and 'Female' to 1
df['gender'] = df['gender'].map({'Male':0,'Female':1})

# %%
df['gender']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    1
# 7040    1
# 7041    0
# 7042    0
# Name: gender, Length: 7043, dtype: int64

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
# Gender : male-0, Female-1
colors = ["#34eb6b" , "#FFC0CB"]
plt.figure(figsize=(20,6))
counts = df['gender'].value_counts()
explode = (0,0.1)
counts.plot(kind='pie',fontsize=12,colors=colors,explode=explode,autopct = '%.1f%%')
plt.title('YES VS NO')
plt.xlabel('Gender',weight='bold',color='#2F0F5D',fontsize=14,labelpad=20)
plt.ylabel('Counts',weight='bold',color='#FFC0CB',fontsize=14,labelpad=20)
plt.legend(labels = counts.index,loc='best')
plt.show()

# %%
# Convert 'No' to 0 and 'Yes' to 1
df['Partner'] = df['Partner'].map({'No':0,'Yes':1})

# %%
df['Partner']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    1
# 7042    0
# Name: Partner, Length: 7043, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
counts = df['Dependents'].value_counts()

colors = ["#34eb6b" , "#FFC0CB"]
ax = counts.plot(kind='bar',color=colors,figsize=(6,4))

for index, value in enumerate(counts):
  ax.text(index,value,str(value), ha='center', va='bottom')

plt.xlabel('Status')
plt.ylabel('Counts')
plt.title('Dependents Distribution')
plt.show()

# %%
# Convert 'No' to 0 and 'Yes' to 1
df['Dependents'] = df['Dependents'].map({'No':0,'Yes':1})

# %%
df['Dependents']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    0
# 7042    0
# Name: Dependents, Length: 7043, dtype: int64

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
counts = df['PhoneService'].value_counts()

colors = ["#34eb6b" , "#FFC0CB"]
ax = counts.plot(kind='bar',color=colors,figsize=(6,4))

for index, value in enumerate(counts):
  ax.text(index,value,str(value), ha='center', va='bottom')

plt.xlabel('Status')
plt.ylabel('Counts')
plt.title('PhoneService Distribution')
plt.show()

# %%
# Convert 'No' to 0 and 'Yes' to 1
df['PhoneService'] = df['PhoneService'].map({'No':0,'Yes':1})

# %%
df['PhoneService']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 7038    1
# 7039    1
# 7040    0
# 7041    1
# 7042    1
# Name: PhoneService, Length: 7043, dtype: int64

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
colors = ["#2B299B" , "#3B74C9" , "#85DFE3"]

plt.figure(figsize = (20, 6))

counts = df["MultipleLines"].value_counts()
explode = (0, 0.1  , 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Status')
plt.xlabel('Status', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Count', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
# Convert 'No phone service' to 0 & Convert 'No' to 0 and 'Yes' to 1
mapping_dict = {'No phone service': 0, 'No': 0, 'Yes': 1}
df['MultipleLines'] = df['MultipleLines'].map(mapping_dict)

# %%
df['MultipleLines']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    0
# 7041    1
# 7042    0
# Name: MultipleLines, Length: 7043, dtype: int64

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 6723       0              0        0           0      46             1
# 964        0              0        0           0       1             1
# 5331       0              0        1           1      44             0
# 4311       1              0        0           0       7             0
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 6723              0              No  No internet service  No internet service
# 964               0             DSL                   No                   No
# 5331              0             DSL                  Yes                  Yes
# 4311              0             DSL                   No                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6723  No internet service  No internet service  No internet service
# 964                    No                   No                   No
# 5331                  Yes                  Yes                   No
# 4311                   No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6723  No internet service        Two year               No
# 964                    No  Month-to-month              Yes
# 5331                  Yes        Two year              Yes
# 4311                  Yes  Month-to-month              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 6723  Bank transfer (automatic)           20.05          902    No
# 964                Mailed check           45.70         45.7   Yes
# 5331    Credit card (automatic)           54.05       2375.2    No
# 4311    Credit card (automatic)           40.10        293.3   Yes

# %%
# now we have these columns : [InternetService, Contract, PaymentMethod] - in these columns we cant use Label Encoding or any other encoding so we use this one hot encoding
# Using sklearn OneHotEncoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.InternetService = le.fit_transform(df.InternetService)
df.Contract = le.fit_transform(df.Contract)
df.PaymentMethod = le.fit_transform(df.PaymentMethod)

# %%
# To avoid redundancy, One function to pre-process them all
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3506       0              0        0           0      19             1
# 6475       1              0        0           1      19             1
# 2025       1              0        1           1      72             1
# 3186       1              0        1           1      58             1
#
#       MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# 3506              1                1            Yes           No
# 6475              1                0            Yes          Yes
# 2025              1                1            Yes          Yes
# 3186              0                2             No           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 3506              Yes          No          No              No         0
# 6475               No         Yes         Yes              No         0
# 2025              Yes         Yes         Yes             Yes         2
# 3186               No          No          No              No         2
#
#      PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges Churn
# 3506              Yes              2           84.75      1651.95    No
# 6475              Yes              3           75.90       1375.6    No
# 2025              Yes              0          116.85       8477.7    No
# 3186               No              1           20.30      1160.75    No

# %%
df['MultipleLines'].isnull().sum()
# Out:
# np.int64(0)

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']

# %%
for col in yes_no_columns:
  df[col].replace({'Yes':1,'No':0},inplace=True)
# Out:
# /tmp/ipython-input-1367723158.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace({'Yes':1,'No':0},inplace=True)
# /tmp/ipython-input-1367723158.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col].replace({'Yes':1,'No':0},inplace=True)

# %%
# now TotalCharges

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 6824       1              1        0           0      66             1
# 4551       0              0        1           1      56             1
# 441        1              1        0           0      49             1
# 4918       0              0        1           1      51             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 6824              1                1               0             1
# 4551              1                1               0             1
# 441               1                1               1             0
# 4918              0                2               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 6824                 0            0            0                0         0
# 4551                 0            1            1                0         0
# 441                  0            0            1                1         0
# 4918                 0            0            0                0         2
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges  Churn
# 6824                 1              1           80.45      5224.35      1
# 4551                 1              1           96.95       5432.2      0
# 441                  0              1          101.55       5070.4      0
# 4918                 0              1           19.55      1086.75      0

# %%
# Check the Null Values ...
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(0)

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull().sum()
# Out:
# np.int64(11)

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 488        1              0        1           1       0             0
# 753        0              0        0           1       0             1
# 936        1              0        1           1       0             1
# 1082       0              0        1           1       0             1
# 1340       1              0        1           1       0             0
# 3331       0              0        1           1       0             1
# 3826       0              0        1           1       0             1
# 4380       1              0        1           1       0             1
# 5218       0              0        1           1       0             1
# 6670       1              0        1           1       0             1
# 6754       0              0        0           1       0             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 488               0                0               1             0
# 753               0                2               0             0
# 936               0                0               1             1
# 1082              1                2               0             0
# 1340              0                0               1             1
# 3331              0                2               0             0
# 3826              1                2               0             0
# 4380              0                2               0             0
# 5218              0                2               0             0
# 6670              1                0               0             1
# 6754              1                0               1             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 488                  1            1            1                0         2
# 753                  0            0            0                0         2
# 936                  1            0            1                1         2
# 1082                 0            0            0                0         2
# 1340                 1            1            1                0         2
# 3331                 0            0            0                0         2
# 3826                 0            0            0                0         2
# 4380                 0            0            0                0         2
# 5218                 0            0            0                0         1
# 6670                 1            1            1                0         2
# 6754                 0            1            0                0         2
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges  Churn
# 488                  1              0           52.55                   0
# 753                  0              3           20.25                   0
# 936                  0              3           80.85                   0
# 1082                 0              3           25.75                   0
# 1340                 0              1           56.05                   0
# 3331                 0              3           19.85                   0
# 3826                 0              3           25.35                   0
# 4380                 0              3           20.00                   0
# 5218                 1              3           19.70                   0
# 6670                 0              3           73.35                   0
# 6754                 1              0           61.90                   0

# %%
df.shape
# Out:
# (7043, 20)

# %% [markdown]
# Now Remove rows with space in TotalCharges

# %%
df = df[df.TotalCharges!=' ']
df.shape
# Out:
# (7032, 20)

# %% [markdown]
# Now we are doing MinMaxScaler

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale ])

# %%
df[cols_to_scale].sample(4)
# Out:
#         tenure  MonthlyCharges  TotalCharges
# 2958  0.000000        0.012935      0.000087
# 5258  0.957746        0.860199      0.831012
# 1207  0.112676        0.508955      0.063772
# 5733  0.985915        0.015920      0.150883

# %% [markdown]
# This is the Dataset final summary

# %%
def summary(df):
    summary_df = pd.DataFrame(df.dtypes, columns=['dtypes'])
    summary_df['missing#'] = df.isna().sum()
    summary_df['missing%'] = (df.isna().sum())/len(df)
    summary_df['unique'] = df.nunique().values
    summary_df['count'] = df.count().values
    return summary_df

summary(df).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_17f6b_row0_col1, #T_17f6b_row0_col2, #T_17f6b_row0_col3, #T_17f6b_row0_col4, #T_17f6b_row1_col1, #T_17f6b_row1_col2, #T_17f6b_row1_col3, #T_17f6b_row1_col4, #T_17f6b_row2_col1, #T_17f6b_row2_col2, #T_17f6b_row2_col3, #T_17f6b_row2_col4, #T_17f6b_row3_col1, #T_17f6b_row3_col2, #T_17f6b_row3_col3, #T_17f6b_row3_col4, #T_17f6b_row4_col1, #T_17f6b_row4_col2, #T_17f6b_row4_col4, #T_17f6b_row5_col1, #T_17f6b_row5_col2, #T_17f6b_row5_col3, #T_17f6b_row5_col4, #T_17f6b_row6_col1, #T_17f6b_row6_col2, #T_17f6b_row6_col3, #T_17f6b_row6_col4, #T_17f6b_row7_col1, #T_17f6b_row7_col2, #T_17f6b_row7_col3, #T_17f6b_row7_col4, #T_17f6b_row8_col1, #T_17f6b_row8_col2, #T_17f6b_row8_col3, #T_17f6b_row8_col4, #T_17f6b_row9_col1, #T_17f6b_row9_col2, #T_17f6b_row9_col3, #T_17f6b_row9_col4, #T_17f6b_row10_col1, #T_17f6b_row10_col2, #T_17f6b_row10_col3, #T_17f6b_row10_col4, #T_17f6b_row11_col1, #T_17f6b_row11_col2, #T_17f6b_row11_col3, #T_17f6b_row11_col4, #T_17f6b_row12_col1, #T_17f6b_row12_col2, #T_17f6b_row12_col3, #T_17f6b_row12_col4, #T_17f6b_row13_col1, #T_17f6b_row13_col2, #T_17f6b_row13_col3, #T_17f6b_row13_col4, #T_17f6b_row14_col1, #T_17f6b_row14_col2, #T_17f6b_row14_col3, #T_17f6b_row14_col4, #T_17f6b_row15_col1, #T_17f6b_row15_col2, #T_17f6b_row15_col3, #T_17f6b_row15_col4, #T_17f6b_row16_col1, #T_17f6b_row16_col2, #T_17f6b_row16_col3, #T_17f6b_row16_col4, #T_17f6b_row17_col1, #T_17f6b_row17_col2, #T_17f6b_row17_col4, #T_17f6b_row18_col1, #T_17f6b_row18_col2, #T_17f6b_row18_col4, #T_17f6b_row19_col1, #T_17f6b_row19_col2, #T_17f6b_row19_col3, #T_17f6b_row19_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_17f6b_row4_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_17f6b_row17_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_17f6b_row18_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_17f6b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17f6b_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_17f6b_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_17f6b_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_17f6b_level0_col3" class="col_heading level0 col3" >unique</th>
#       <th id="T_17f6b_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17f6b_level0_row0" class="row_heading level0 row0" >gender</th>
#       <td id="T_17f6b_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_17f6b_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_17f6b_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_17f6b_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_17f6b_row0_col4" class="data row0 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row1" class="row_heading level0 row1" >SeniorCitizen</th>
#       <td id="T_17f6b_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_17f6b_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_17f6b_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_17f6b_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_17f6b_row1_col4" class="data row1 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row2" class="row_heading level0 row2" >Partner</th>
#       <td id="T_17f6b_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_17f6b_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_17f6b_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_17f6b_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_17f6b_row2_col4" class="data row2 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row3" class="row_heading level0 row3" >Dependents</th>
#       <td id="T_17f6b_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_17f6b_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_17f6b_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_17f6b_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_17f6b_row3_col4" class="data row3 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row4" class="row_heading level0 row4" >tenure</th>
#       <td id="T_17f6b_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_17f6b_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_17f6b_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_17f6b_row4_col3" class="data row4 col3" >72</td>
#       <td id="T_17f6b_row4_col4" class="data row4 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row5" class="row_heading level0 row5" >PhoneService</th>
#       <td id="T_17f6b_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_17f6b_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_17f6b_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_17f6b_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_17f6b_row5_col4" class="data row5 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row6" class="row_heading level0 row6" >MultipleLines</th>
#       <td id="T_17f6b_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_17f6b_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_17f6b_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_17f6b_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_17f6b_row6_col4" class="data row6 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row7" class="row_heading level0 row7" >InternetService</th>
#       <td id="T_17f6b_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_17f6b_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_17f6b_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_17f6b_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_17f6b_row7_col4" class="data row7 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row8" class="row_heading level0 row8" >OnlineSecurity</th>
#       <td id="T_17f6b_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_17f6b_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_17f6b_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_17f6b_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_17f6b_row8_col4" class="data row8 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row9" class="row_heading level0 row9" >OnlineBackup</th>
#       <td id="T_17f6b_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_17f6b_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_17f6b_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_17f6b_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_17f6b_row9_col4" class="data row9 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row10" class="row_heading level0 row10" >DeviceProtection</th>
#       <td id="T_17f6b_row10_col0" class="data row10 col0" >int64</td>
#       <td id="T_17f6b_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_17f6b_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_17f6b_row10_col3" class="data row10 col3" >2</td>
#       <td id="T_17f6b_row10_col4" class="data row10 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row11" class="row_heading level0 row11" >TechSupport</th>
#       <td id="T_17f6b_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_17f6b_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_17f6b_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_17f6b_row11_col3" class="data row11 col3" >2</td>
#       <td id="T_17f6b_row11_col4" class="data row11 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17f6b_level0_row12" class="row_heading level0 row12" >StreamingTV</th>
#       <td id="T_17f6b_row12_col0" class="data row12 col0" >int64</td>
#       <td id="T_17f6b_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_17f6b_row12_col2" class="data row12 col2" >0.000000</td>

# %% [markdown]
# Determine Predictor & Target

# %%
X = df.drop('Churn',axis='columns')
y = df['Churn']

# %%
X.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 704        0              0        0           0  0.042254             1
# 2804       0              0        1           0  0.112676             0
# 6281       0              0        0           0  0.070423             1
# 3455       0              0        0           0  0.000000             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 704               0                0               0             1
# 2804              0                0               0             0
# 6281              0                2               0             0
# 3455              0                1               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 704                  0            0            0                0         0
# 2804                 0            0            0                0         1
# 6281                 0            0            0                0         1
# 3455                 0            0            1                1         0
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges
# 704                  0              3        0.308458      0.021884
# 2804                 0              0        0.058209      0.027810
# 6281                 0              3        0.023383      0.011285
# 3455                 1              2        0.719403      0.008279

# %%
y.sample(3)
# Out:
# 6715    0
# 5140    0
# 5914    0
# Name: Churn, dtype: int64

# %% [markdown]
# now we are going to split the data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 19)

# %%
X_test.shape
# Out:
# (1407, 19)

# %% [markdown]
# BUILDING THE ANN MODEL

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(15,input_shape=(19,), activation='relu'),
     keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7134 - loss: 0.5632
# Epoch 2/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7420 - loss: 0.4671
# Epoch 3/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7750 - loss: 0.4401
# Epoch 4/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7988 - loss: 0.4180
# Epoch 5/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7962 - loss: 0.4244
# Epoch 6/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7934 - loss: 0.4285
# Epoch 7/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.4051
# Epoch 8/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7970 - loss: 0.4112
# Epoch 9/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8045 - loss: 0.4150
# Epoch 10/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8015 - loss: 0.4138
# Epoch 11/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8140 - loss: 0.4039
# Epoch 12/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8036 - loss: 0.4170
# Epoch 13/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8054 - loss: 0.4158
# Epoch 14/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.4001
# Epoch 15/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8084 - loss: 0.4143
# Epoch 16/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.3998
# Epoch 17/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8083 - loss: 0.4096
# Epoch 18/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8059 - loss: 0.4047
# Epoch 19/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8199 - loss: 0.4017
# Epoch 20/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8181 - loss: 0.3898
# Epoch 21/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8093 - loss: 0.4062
# Epoch 22/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8188 - loss: 0.3909
# Epoch 23/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8065 - loss: 0.4029
# Epoch 24/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8206 - loss: 0.3936
# Epoch 25/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8110 - loss: 0.4036
# Epoch 26/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8177 - loss: 0.4035
# Epoch 27/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8157 - loss: 0.3974
# Epoch 28/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8091 - loss: 0.4006
# Epoch 29/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8131 - loss: 0.3945
# Epoch 30/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8196 - loss: 0.3948
# Epoch 31/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.4009
# Epoch 32/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8254 - loss: 0.3896
# Epoch 33/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8130 - loss: 0.3913
# Epoch 34/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8216 - loss: 0.3852
# Epoch 35/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8162 - loss: 0.3925
# Epoch 36/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8216 - loss: 0.3901
# Epoch 37/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8220 - loss: 0.3883
# Epoch 38/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8094 - loss: 0.4004
# Epoch 39/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8144 - loss: 0.3949
# Epoch 40/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8223 - loss: 0.3864
# Epoch 41/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8108 - loss: 0.3972
# Epoch 42/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8047 - loss: 0.4045
# Epoch 43/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8241 - loss: 0.3823
# Epoch 44/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8233 - loss: 0.3839
# Epoch 45/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8187 - loss: 0.3916
# Epoch 46/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8189 - loss: 0.3886
# Epoch 47/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8153 - loss: 0.3898
# Epoch 48/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8255 - loss: 0.3814
# Epoch 49/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8106 - loss: 0.3967
# Epoch 50/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8117 - loss: 0.3964
# Epoch 51/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8207 - loss: 0.3938
# Epoch 52/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8186 - loss: 0.3871
# Epoch 53/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8216 - loss: 0.3795
# Epoch 54/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8210 - loss: 0.3870
# Epoch 55/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8260 - loss: 0.3761
# Epoch 56/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.3907
# Epoch 57/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8132 - loss: 0.3926
# Epoch 58/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8088 - loss: 0.3977
# Epoch 59/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8200 - loss: 0.3839
# Epoch 60/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8257 - loss: 0.3799
# Epoch 61/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8179 - loss: 0.3872
# Epoch 62/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8213 - loss: 0.3771
# Epoch 63/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8299 - loss: 0.3735
# Epoch 64/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8166 - loss: 0.3893
# Epoch 65/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8241 - loss: 0.3825
# Epoch 66/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8211 - loss: 0.3790
# Epoch 67/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8147 - loss: 0.3827
# Epoch 68/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8282 - loss: 0.3760
# Epoch 69/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8258 - loss: 0.3857
# Epoch 70/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8188 - loss: 0.3789
# Epoch 71/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8339 - loss: 0.3645
# Epoch 72/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8294 - loss: 0.3700
# Epoch 73/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8209 - loss: 0.3863
# Epoch 74/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8232 - loss: 0.3750
# Epoch 75/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.3888
# Epoch 76/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8278 - loss: 0.3740
# Epoch 77/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8282 - loss: 0.3706
# Epoch 78/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8254 - loss: 0.3768
# Epoch 79/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8133 - loss: 0.3993
# Epoch 80/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8228 - loss: 0.3780
# Epoch 81/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8137 - loss: 0.3880
# Epoch 82/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8181 - loss: 0.3857
# Epoch 83/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8215 - loss: 0.3830
# Epoch 84/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8243 - loss: 0.3792
# Epoch 85/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8177 - loss: 0.3873
# Epoch 86/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8047 - loss: 0.3887
# Epoch 87/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8220 - loss: 0.3833
# Epoch 88/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8254 - loss: 0.3752
# Epoch 89/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8157 - loss: 0.3917
# Epoch 90/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8166 - loss: 0.3854
# Epoch 91/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8222 - loss: 0.3749
# Epoch 92/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8248 - loss: 0.3803
# Epoch 93/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8253 - loss: 0.3769
# Epoch 94/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.3918
# Epoch 95/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8211 - loss: 0.3752
# Epoch 96/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8164 - loss: 0.3782
# Epoch 97/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8247 - loss: 0.3671
# Epoch 98/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8263 - loss: 0.3740
# Epoch 99/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8282 - loss: 0.3769
# Epoch 100/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8189 - loss: 0.3760

# %% [markdown]
# MODEL EVALUATION

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8041 - loss: 0.4540
# [0.47243601083755493, 0.7818052768707275]

# %% [markdown]
# MODEL METRICS

# %%
from sklearn.metrics import confusion_matrix , classification_report

# %%
yp = model.predict(X_test)

y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       999
#            1       0.67      0.49      0.56       408
#
#     accuracy                           0.78      1407
#    macro avg       0.74      0.69      0.71      1407
# weighted avg       0.77      0.78      0.77      1407

# %%
report = classification_report(y_test, y_pred, output_dict=True)
rep = pd.DataFrame(report).transpose()

# Create a heatmap of the classification report
plt.figure(figsize=(14, 8))
sns.heatmap(df.iloc[:-1, :4], annot=True, cmap='Blues')
plt.title('Classification Report')
plt.show()

# %%
# Extract metrics for each class
classes = [str(key) for key in range(len(report) - 3)]  # Extract class labels
precision = [report[key]['precision'] for key in classes]
recall = [report[key]['recall'] for key in classes]
f1_score = [report[key]['f1-score'] for key in classes]

# %%
# Plotting the metrics using a bar chart
plt.figure(figsize=(12, 6))
barWidth = 0.25
r1 = range(len(classes))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, precision, color='#4b0082', width=barWidth, edgecolor='grey', label='Precision')
plt.bar(r2, recall, color='#f0f8ff', width=barWidth, edgecolor='grey', label='Recall')
plt.bar(r3, f1_score, color='#ff7f50', width=barWidth, edgecolor='grey', label='F1-score')

plt.xlabel('Class', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(classes))], classes)
plt.legend()
plt.title("Classification Report Metrics")
plt.show()

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
